# %% [markdown]
# # __Data pre-processing and data Wrangling__
# ![image](img/1.jpg)
# ![image](img/2.jpg)
# ![image](img/3.jpg)

# %% [markdown]
# # ___Content___
#
# 1- Missing values
#
# 2- Data Formatting
#
# 3- Data Normalization
#  - scaling
#  - centralizing
#
# 4- Data Binning
#  - for groups of Data
#
# 5- Making dummies of catagorical data
#  - Catagorical ------ Numerical
#  - Convert from catagorical to numerial or vise versa.

# %%
# install libraries
# pip install pandas
# pip install seaborn
# pip install numpy

# %%
# import lib
import pandas as pd
import numpy as np 
import seaborn as sns

# %%
kashti=sns.load_dataset('titanic')
ks1= kashti
ks2= kashti

# same dataset of kashti but we will use it as different names.

# %%
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# simple operation ( math operator)
# change in age
(kashti['age']+1).head(10)
# we can multiply, if our data is numnerical,
# if data is catagorical/not-numerical then can do concatination or string function etc
# Out:
# 0    23.0
# 1    39.0
# 2    27.0
# 3    36.0
# 4    36.0
# 5     NaN
# 6    55.0
# 7     3.0
# 8    28.0
# 9    15.0
# Name: age, dtype: float64

# %% [markdown]
# ## Dealing with Missing Values
# - in a dataset missing values are either ? or N/A or NaN, or 0 or a back cell.
# - ab kabi data na ho kisi aik row main kisi b aik parameter ka
#
# > Steps:
#
#   1- Try to collect data again
#
#   2- Delete varibale of missing values if it does not affect data set or remove row or data entry.
#
#   3- Replace a missing values:
#
#      1. How?
#          1. Average value of entire variales or similar data point
#          2. Frequency or MODE replacement , (rarely use)
#          3. Replace base on other functions (Data sampler knows that)
#          4. ML machine learning algorithm can be used
#          5. Leave it like that
#
#       2. Why?
#          1. Its better because no loss in data
#          2. less accurate

# %%
# where exactly missing values are?
kashti.isnull().sum()
# it will count missing values
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# use drop.na method, it will drops all missing values
print(kashti.shape)
kashti.dropna(subset=['deck'], axis=0, inplace=True) # this will remove specifically 
# axix 0 = y-axis while axis 1= y-axix, | columns are up-to downwards, while rows are left to right  
# inplace = True modifies the data frame, False will not modifies or data.
# Out:
# (203, 15)

# %%
kashti.isnull().sum()  # find again null values# 
# here now "deck" contain zero null values now.
# Out:
# survived        0
# pclass          0
# sex             0
# age            19
# sibsp           0
# parch           0
# fare            0
# embarked        2
# class           0
# who             0
# adult_male      0
# deck            0
# embark_town     2
# alive           0
# alone           0
# dtype: int64

# %%
# to drop all na's in anywhere in data
kashti.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti.dropna().isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
kashti.shape
# here we have deleted too much data , it would not be usefull. need more methods. only 15 rows and 203 colums left.
# Out:
# (203, 15)

# %% [markdown]
# ### _We must be assured that after removing missing values our data is still sufficient or not?_

# %%
ks1.isnull().sum()
# again we will load dataset in start column like
# kashti=sns.load_dataset('titanic')
# ks1= kashti
# ks2= kashti
# Out:
# survived        0
# pclass          0
# sex             0
# age            19
# sibsp           0
# parch           0
# fare            0
# embarked        2
# class           0
# who             0
# adult_male      0
# deck            0
# embark_town     2
# alive           0
# alone           0
# dtype: int64

# %% [markdown]
# _Replacing missing values with the average (mean) of that column_

# %%
# finding an avergae (mean)
mean = ks1['age'].mean()
mean
# Out:
# 35.77945652173913

# %%
# replcing NaN with mean of the dataset (updating as well)
ks1['age'] = ks1['age'].replace(np.nan , mean)

# %%
ks1.isnull().sum()
# here age is replaced with mean 29.6
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# #  ASSIGNMENT: Here we will replace 'deck' value with mean

# %%
# here we will replace 'deck' value with mean
# deck, emarked and emark_town are catagorical values and can only be replaced with MODE as below in one go:
# find mode of multiple columns in one code
ks1_multi=ks1.filter(['deck','embarked','embark_town']).mode()
ks1_multi
# Out:
#   deck embarked  embark_town
# 0    C        S  Southampton

# %%
# creat a sub-set and replace nan with mode in one code in all three columns.
cols=['deck','embarked','embark_town']
ks1[cols]=ks1[cols].fillna(ks1.mode().iloc[0])

# %%
ks1.isnull().sum()
# done with help.
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# # _Data Formating / Standarization / Duplication_
# ## - Easy to gather
# ## - Easy to workwith
#     -    Faisalabad (FSD)
#     -    Lahore (LHR)
#     -    convert g to kg or similar unit for all
#     -    one standard unit for each column etc

# %%
# know the data type and convert it into the known one
kashti.dtypes
ks1.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
# use this method to convert datatypes from one to another formate numeric, etc
kashti['survived']= kashti['survived'].astype('float64') 
kashti.dtypes
# Out:
# survived        float64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
# here we will convert the age into days instead of years
ks1['age']=ks1['age']*365
ks1.head(10)
# to remove zeroes from age, we just need the datatype of age from float64 to int64
# Out:
#     survived  pclass     sex          age  sibsp  parch      fare embarked  \
# 1        1.0       1  female  13870.00000      1      0   71.2833        C
# 3        1.0       1  female  12775.00000      1      0   53.1000        S
# 6        0.0       1    male  19710.00000      0      0   51.8625        S
# 10       1.0       3  female   1460.00000      1      1   16.7000        S
# 11       1.0       1  female  21170.00000      0      0   26.5500        S
# 21       1.0       2    male  12410.00000      0      0   13.0000        S
# 23       1.0       1    male  10220.00000      0      0   35.5000        S
# 27       0.0       1    male   6935.00000      3      2  263.0000        S
# 31       1.0       1  female  13059.50163      1      0  146.5208        C
# 52       1.0       1  female  17885.00000      1      0   76.7292        C
#
#      class    who  adult_male deck  embark_town alive  alone
# 1    First  woman       False    C    Cherbourg   yes  False
# ...

# %%
# always rename afterwards
ks1.rename(columns={'age': "age_in_days"}, inplace=True) # true mena change in dataset
ks1.head()
# Out:
#     survived  pclass     sex  age_in_days  sibsp  parch     fare embarked  \
# 1        1.0       1  female      13870.0      1      0  71.2833        C
# 3        1.0       1  female      12775.0      1      0  53.1000        S
# 6        0.0       1    male      19710.0      0      0  51.8625        S
# 10       1.0       3  female       1460.0      1      1  16.7000        S
# 11       1.0       1  female      21170.0      0      0  26.5500        S
#
#     class    who  adult_male deck  embark_town alive  alone
# 1   First  woman       False    C    Cherbourg   yes  False
# 3   First  woman       False    C  Southampton   yes  False
# 6   First    man        True    E  Southampton    no   True
# 10  Third  child       False    G  Southampton   yes  False
# 11  First  woman       False    C  Southampton   yes   True

# %% [markdown]
# # _Data Normalization_
# - 1- Uniform the data
# - 2- Making user they have same impact
# - 3- Eik machli sumandar mn ha or eik jar mn
# - 4- Also for computational reasons

# %%
kashti.head()
# Out:
#     survived  pclass     sex  age_in_days  sibsp  parch     fare embarked  \
# 1        1.0       1  female      13870.0      1      0  71.2833        C
# 3        1.0       1  female      12775.0      1      0  53.1000        S
# 6        0.0       1    male      19710.0      0      0  51.8625        S
# 10       1.0       3  female       1460.0      1      1  16.7000        S
# 11       1.0       1  female      21170.0      0      0  26.5500        S
#
#     class    who  adult_male deck  embark_town alive  alone
# 1   First  woman       False    C    Cherbourg   yes  False
# 3   First  woman       False    C  Southampton   yes  False
# 6   First    man        True    E  Southampton    no   True
# 10  Third  child       False    G  Southampton   yes  False
# 11  First  woman       False    C  Southampton   yes   True

# %%
ks4= kashti[['age_in_days','fare']]
ks4.head()
# Out:
#     age_in_days     fare
# 1       13870.0  71.2833
# 3       12775.0  53.1000
# 6       19710.0  51.8625
# 10       1460.0  16.7000
# 11      21170.0  26.5500

# %% [markdown]
# ***- The above data is really in a wide range and we need to normalize because it is really hard to compare.***
#
# ***- Normaliztion change the values to the range of 0-1 (now both variables has similar influence on our model).***

# %% [markdown]
# ## Method of Normalziation
#
# 1. Simple feature scaling
#     - x(new)=x(old)/x(max)
# 2. Min-Max method
# 3. Z-score (standard score) -3 to +3
# 4. Log transformation

# %%
# Simple feature scalling
ks4['fare'] = ks4['fare']/ks4['fare'].max()
ks4.head()
# Out:
# C:\Users\Junaid\AppData\Local\Temp\ipykernel_12384\3341921790.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks4['fare'] = ks4['fare']/ks4['fare'].max()
#     age_in_days      fare
# 1       13870.0  0.139136
# 3       12775.0  0.103644
# 6       19710.0  0.101229
# 10       1460.0  0.032596
# 11      21170.0  0.051822

# %%
# Simple feature scalling
ks4['age_in_days'] = ks4['age_in_days']/ks4['age_in_days'].max()
ks4.head()
# Out:
# C:\Users\Junaid\AppData\Local\Temp\ipykernel_12384\405509985.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks4['age_in_days'] = ks4['age_in_days']/ks4['age_in_days'].max()
#     age_in_days      fare
# 1        0.4750  0.139136
# 3        0.4375  0.103644
# 6        0.6750  0.101229
# 10       0.0500  0.032596
# 11       0.7250  0.051822

# %%
# above both function in same code
ks4['fare'] = ks4['fare']/ks4['fare'].max()
ks4['age_in_days'] = ks4['age_in_days']/ks4['age_in_days'].max()
ks4.head()
# Out:
# C:\Users\Junaid\AppData\Local\Temp\ipykernel_12384\597453143.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks4['fare'] = ks4['fare']/ks4['fare'].max()
# C:\Users\Junaid\AppData\Local\Temp\ipykernel_12384\597453143.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks4['age_in_days'] = ks4['age_in_days']/ks4['age_in_days'].max()
#     age_in_days      fare
# 1        0.4750  0.139136
# 3        0.4375  0.103644
# 6        0.6750  0.101229
# 10       0.0500  0.032596
# ...

# %%
# MIN-MAX method
ks4['fare']= (ks4['fare']-ks4['fare'].min()) / (ks4['fare'].max()-ks4['fare'].min())
ks4.head()

# its range fall from -1 to 1 (-1,0,1)
# Out:
# C:\Users\Junaid\AppData\Local\Temp\ipykernel_12384\1678390559.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks4['fare']= (ks4['fare']-ks4['fare'].min()) / (ks4['fare'].max()-ks4['fare'].min())
#     age_in_days      fare
# 1        0.4750  0.139136
# 3        0.4375  0.103644
# 6        0.6750  0.101229
# 10       0.0500  0.032596
# 11       0.7250  0.051822

# %%
# Z-score (standard score)
ks4['fare'] = (ks4['fare']-ks4['fare'].mean()) / ks4['fare'].std()
ks4.head()

# its range fall from -3 to 3
# Out:
# C:\Users\Junaid\AppData\Local\Temp\ipykernel_12384\1751094085.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks4['fare'] = (ks4['fare']-ks4['fare'].mean()) / ks4['fare'].std()
#     age_in_days      fare
# 1        0.4750 -0.067879
# 3        0.4375 -0.311883
# 6        0.6750 -0.328489
# 10       0.0500 -0.800339
# 11       0.7250 -0.668161

# %%
# log transformation
ks4['fare'] = np.log(ks4['fare'])
ks4.head()
# Out:
# C:\Users\Junaid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Junaid\AppData\Local\Temp\ipykernel_12384\1047238464.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks4['fare'] = np.log(ks4['fare'])
#     age_in_days  fare
# 1        0.4750   NaN
# 3        0.4375   NaN
# 6        0.6750   NaN
# 10       0.0500   NaN
# 11       0.7250   NaN

# %%
# above our data is already very small so ,, but we can use log to normalize real data. now we can try this.
# we will add "ks" as a new fresh dataset
ks = sns.load_dataset('titanic')
ks.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
ks = sns.load_dataset('titanic')
ks['fare'] = np.log(ks['fare'])
ks.head() 

# normalization is called human readable or machine readabli size , dafa difference is same in "fare" but ranges is smaller now!
# Out:
# C:\Users\Junaid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#    survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 0         0       3    male  22.0      1      0  1.981001        S  Third
# 1         1       1  female  38.0      1      0  4.266662        C  First
# 2         1       3  female  26.0      0      0  2.070022        S  Third
# 3         1       1  female  35.0      1      0  3.972177        S  First
# 4         0       3    male  35.0      0      0  2.085672        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# ...

# %% [markdown]
# # ___Binning___
#    - Grouping of values into smaller number and different columns
#    - Convert numeric into catagorical and vice versa i.e AGE bin into (jawan,bachay,boorhay) or 1-16, 17-35, 35- etc
#    - To have better understandigs of groups
#         - low vs mid vs high prices

# %%
# we will check data first again and again
ks.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 0         0       3    male  22.0      1      0  1.981001        S  Third
# 1         1       1  female  38.0      1      0  4.266662        C  First
# 2         1       3  female  26.0      0      0  2.070022        S  Third
# 3         1       1  female  35.0      1      0  3.972177        S  First
# 4         0       3    male  35.0      0      0  2.085672        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
min_value = ks['age'].min()
max_value = ks['age'].max()
print(min_value)
print(max_value)
# Out:
# 0.42
# 80.0

# %%
import numpy as np
bins = np.linspace(min_value,max_value,4)
bins
# Out:
# array([ 0.42      , 26.94666667, 53.47333333, 80.        ])

# %%
labels = ["Bachay","Jawan","Boorhay"]

# %%
ks['bins'] = pd.cut(ks['age'], bins=bins, labels=labels, include_lowest=True)
ks.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 0         0       3    male  22.0      1      0  1.981001        S  Third
# 1         1       1  female  38.0      1      0  4.266662        C  First
# 2         1       3  female  26.0      0      0  2.070022        S  Third
# 3         1       1  female  35.0      1      0  3.972177        S  First
# 4         0       3    male  35.0      0      0  2.085672        S  Third
#
#      who  adult_male deck  embark_town alive  alone    bins
# 0    man        True  NaN  Southampton    no  False  Bachay
# 1  woman       False    C    Cherbourg   yes  False   Jawan
# 2  woman       False  NaN  Southampton   yes   True  Bachay
# 3  woman       False    C  Southampton   yes  False   Jawan
# 4    man        True  NaN  Southampton    no   True   Jawan

# %%
# Alternatively, we can set the edges of each bin manually.
import matplotlib.pyplot as plt
bins = [ 0, 15, 35, 81 ]
ks['bin_cut_manual'] = pd.cut(ks['age'] , bins=bins, labels=labels, include_lowest=True)
ks.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 0         0       3    male  22.0      1      0  1.981001        S  Third
# 1         1       1  female  38.0      1      0  4.266662        C  First
# 2         1       3  female  26.0      0      0  2.070022        S  Third
# 3         1       1  female  35.0      1      0  3.972177        S  First
# 4         0       3    male  35.0      0      0  2.085672        S  Third
#
#      who  adult_male deck  embark_town alive  alone    bins bin_cut_manual
# 0    man        True  NaN  Southampton    no  False  Bachay          Jawan
# 1  woman       False    C    Cherbourg   yes  False   Jawan        Boorhay
# 2  woman       False  NaN  Southampton   yes   True  Bachay          Jawan
# 3  woman       False    C  Southampton   yes  False   Jawan          Jawan
# 4    man        True  NaN  Southampton    no   True   Jawan          Jawan

# %%
bins = np.linspace(min(ks['age']), max(ks['age']), 15000)
age_groups = ["Bachay","Jawan","Boorhay"]
ks.head()
# here age is age_in_days
# ks['age'] = pd.cut(ks['age'], bins, labels=age_groups, include_lowest=True)
# Out:
#    survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 0         0       3    male  22.0      1      0  1.981001        S  Third
# 1         1       1  female  38.0      1      0  4.266662        C  First
# 2         1       3  female  26.0      0      0  2.070022        S  Third
# 3         1       1  female  35.0      1      0  3.972177        S  First
# 4         0       3    male  35.0      0      0  2.085672        S  Third
#
#      who  adult_male deck  embark_town alive  alone    bins bin_cut_manual
# 0    man        True  NaN  Southampton    no  False  Bachay          Jawan
# 1  woman       False    C    Cherbourg   yes  False   Jawan        Boorhay
# 2  woman       False  NaN  Southampton   yes   True  Bachay          Jawan
# 3  woman       False    C  Southampton   yes  False   Jawan          Jawan
# 4    man        True  NaN  Southampton    no   True   Jawan          Jawan

# %%
kashti.head()
# Out:
#     survived  pclass     sex  age_in_days  sibsp  parch     fare embarked  \
# 1        1.0       1  female      13870.0      1      0  71.2833        C
# 3        1.0       1  female      12775.0      1      0  53.1000        S
# 6        0.0       1    male      19710.0      0      0  51.8625        S
# 10       1.0       3  female       1460.0      1      1  16.7000        S
# 11       1.0       1  female      21170.0      0      0  26.5500        S
#
#     class    who  adult_male deck  embark_town alive  alone
# 1   First  woman       False    C    Cherbourg   yes  False
# 3   First  woman       False    C  Southampton   yes  False
# 6   First    man        True    E  Southampton    no   True
# 10  Third  child       False    G  Southampton   yes  False
# 11  First  woman       False    C  Southampton   yes   True

# %% [markdown]
# ### converting catagories into dummies
# - easy to use for computation
# - Male, Female (0,1)

# %%
ks4 = kashti
ks4.head()
# Out:
#     survived  pclass     sex  age_in_days  sibsp  parch     fare embarked  \
# 1        1.0       1  female      13870.0      1      0  71.2833        C
# 3        1.0       1  female      12775.0      1      0  53.1000        S
# 6        0.0       1    male      19710.0      0      0  51.8625        S
# 10       1.0       3  female       1460.0      1      1  16.7000        S
# 11       1.0       1  female      21170.0      0      0  26.5500        S
#
#     class    who  adult_male deck  embark_town alive  alone
# 1   First  woman       False    C    Cherbourg   yes  False
# 3   First  woman       False    C  Southampton   yes  False
# 6   First    man        True    E  Southampton    no   True
# 10  Third  child       False    G  Southampton   yes  False
# 11  First  woman       False    C  Southampton   yes   True

# %%
sex_dummies = pd.get_dummies(ks4.sex, prefix='sex')

# %%
ks4_with_dummies = pd.concat([ks4, sex_dummies], axis='columns')
ks4_with_dummies.head()
# Out:
#     survived  pclass     sex  age_in_days  sibsp  parch     fare embarked  \
# 1        1.0       1  female      13870.0      1      0  71.2833        C
# 3        1.0       1  female      12775.0      1      0  53.1000        S
# 6        0.0       1    male      19710.0      0      0  51.8625        S
# 10       1.0       3  female       1460.0      1      1  16.7000        S
# 11       1.0       1  female      21170.0      0      0  26.5500        S
#
#     class    who  adult_male deck  embark_town alive  alone  sex_female  \
# 1   First  woman       False    C    Cherbourg   yes  False           1
# 3   First  woman       False    C  Southampton   yes  False           1
# 6   First    man        True    E  Southampton    no   True           0
# 10  Third  child       False    G  Southampton   yes  False           1
# 11  First  woman       False    C  Southampton   yes   True           1
#
#     sex_male
# 1          0
# 3          0
# 6          1
# 10         0
# 11         0

# %%
# now we need to remove age column which is text data, and already placed with dummies variables so we can safely removed it.

# %%
ks4_with_dummies.drop('sex', axis='columns', inplace=True)

# %%
ks4_with_dummies.head()
# Out:
#     survived  pclass  age_in_days  sibsp  parch     fare embarked  class  \
# 1        1.0       1      13870.0      1      0  71.2833        C  First
# 3        1.0       1      12775.0      1      0  53.1000        S  First
# 6        0.0       1      19710.0      0      0  51.8625        S  First
# 10       1.0       3       1460.0      1      1  16.7000        S  Third
# 11       1.0       1      21170.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone  sex_female  sex_male
# 1   woman       False    C    Cherbourg   yes  False           1         0
# 3   woman       False    C  Southampton   yes  False           1         0
# 6     man        True    E  Southampton    no   True           0         1
# 10  child       False    G  Southampton   yes  False           1         0
# 11  woman       False    C  Southampton   yes   True           1         0

# %%
pd.get_dummies(ks4['sex'])
# Out:
#      female  male
# 1         1     0
# 3         1     0
# 6         0     1
# 10        1     0
# 11        1     0
# ..      ...   ...
# 871       1     0
# 872       0     1
# 879       1     0
# 887       1     0
# 889       0     1
#
# [203 rows x 2 columns]

# %%
ks.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 0         0       3    male  22.0      1      0  1.981001        S  Third
# 1         1       1  female  38.0      1      0  4.266662        C  First
# 2         1       3  female  26.0      0      0  2.070022        S  Third
# 3         1       1  female  35.0      1      0  3.972177        S  First
# 4         0       3    male  35.0      0      0  2.085672        S  Third
#
#      who  adult_male deck  embark_town alive  alone    bins bin_cut_manual
# 0    man        True  NaN  Southampton    no  False  Bachay          Jawan
# 1  woman       False    C    Cherbourg   yes  False   Jawan        Boorhay
# 2  woman       False  NaN  Southampton   yes   True  Bachay          Jawan
# 3  woman       False    C  Southampton   yes  False   Jawan          Jawan
# 4    man        True  NaN  Southampton    no   True   Jawan          Jawan

# %%
# here we see not changes female and male into 0,1.
# our assignment how to **append** these **dummy values**, how to replace these?
# transfer into dummy values
